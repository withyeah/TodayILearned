# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-52000',
#  '24H_fluctate_rate': '-1.35',
#  'average_price': '3816379.2291',
#  'buy_price': '3777000',
#  'closing_price': '3775000',
#  'date': '1548743153390',
#  'max_price': '3850000',
#  'min_price': '3757000',
#  'opening_price': '3827000',
#  'sell_price': '3780000',
#  'units_traded': '3500.26040732',
#  'volume_1day': '3500.26040732',
#  'volume_7day': '21558.95161339'}

# %%
# 아래에 코드를 작성하세요.
price = int(btc['max_price'])-int(btc['min_price'])+int(btc['opening_price'])
print('상승장' if price > int(btc['max_price']) else '하락장')
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-3.6',
#          '24H_fluctate_rate': '-4.99',
#          'average_price': '70.1842',
#          'buy_price': '68.5',
#          'closing_price': '68.5',
#          'max_price': '74.8',
#          'min_price': '66',
#          'opening_price': '72.1',
#          'sell_price': '72.5',
#          'units_traded': '360042.23410345',
#          'volume_1day': '360042.23410345',
#          'volume_7day': '5675249.397032159682731299'},
#  'ADA': {'24H_fluctate': '-1.2',
#          '24H_fluctate_rate': '-2.82',
#          'average_price': '42.2141',
#          'buy_price': '41.3',
#          'closing_price': '41.3',
#          'max_price': '43.3',
#          'min_price': '41.1',
#          'opening_price': '42.5',
#          'sell_price': '41.7',
#          'units_traded': '8424881.71248409',
#          'volume_1day': '8424881.71248409',
#          'volume_7day': '51914824.96992435'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '3',
#         '24H_fluctate_rate': '0.75',
#         'average_price': '406.7437',
#         'buy_price': '403',
#         'closing_price': '403',
#         'max_price': '417',
#         'min_price': '399',
#         'opening_price': '400',
#         'sell_price': '404',
#         'units_traded': '524840.41878079',
#         'volume_1day': '524840.41878079',
#         'volume_7day': '5635803.08782291074057475'},
#  'AMO': {'24H_fluctate': '0.04',
#          '24H_fluctate_rate': '6.34',
#          'average_price': '0.6643',
#          'buy_price': '0.65',
#          'closing_price': '0.67',
#          'max_price': '0.7',
#          'min_price': '0.63',
#          'opening_price': '0.63',
#          'sell_price': '0.67',
#          'units_traded': '200664241.5808343',
#          'volume_1day': '200664241.5808343',
#          'volume_7day': '2936492910.819531449158818423'},
#  'APIS': {'24H_fluctate': '0.25',
#           '24H_fluctate_rate': '13.08',
#           'average_price': '2.12',
#           'buy_price': '2.15',
#           'closing_price': '2.16',
#           'max_price': '2.34',
#           'min_price': '1.88',
#           'opening_price': '1.91',
#           'sell_price': '2.16',
#           'units_traded': '850399669.6799877',
#           'volume_1day': '850399669.6799877',
#           'volume_7day': '29265582962.587958469837938536'},
#  'ARN': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-1.07',
#          'average_price': '285.8243',
#          'buy_price': '274',
#          'closing_price': '276',
#          'max_price': '308',
#          'min_price': '271',
#          'opening_price': '279',
#          'sell_price': '281',
#          'units_traded': '315600.55897867',
#          'volume_1day': '315600.55897867',
#          'volume_7day': '1513763.32501822'},
#  'BAT': {'24H_fluctate': '-7',
#          '24H_fluctate_rate': '-5.46',
#          'average_price': '126.3169',
#          'buy_price': '121',
#          'closing_price': '121',
#          'max_price': '136',
#          'min_price': '121',
#          'opening_price': '128',
#          'sell_price': '124',
#          'units_traded': '433509.65519412',
#          'volume_1day': '433509.65519412',
#          'volume_7day': '1903917.181112992227622529'},
#  'BCD': {'24H_fluctate': '-9',
#          '24H_fluctate_rate': '-1.15',
#          'average_price': '785.0378',
#          'buy_price': '772',
#          'closing_price': '770',
#          'max_price': '803',
#          'min_price': '768',
#          'opening_price': '779',
#          'sell_price': '792',
#          'units_traded': '27057.55150635',
#          'volume_1day': '27057.55150635',
#          'volume_7day': '347040.82242483'},
#  'BCH': {'24H_fluctate': '-3300',
#          '24H_fluctate_rate': '-2.68',
#          'average_price': '122087.6636',
#          'buy_price': '119600',
#          'closing_price': '119700',
#          'max_price': '125800',
#          'min_price': '117000',
#          'opening_price': '123000',
#          'sell_price': '119900',
#          'units_traded': '30029.65679975',
#          'volume_1day': '30029.65679975',
#          'volume_7day': '174779.05666796'},
#  'BHPC': {'24H_fluctate': '7',
#           '24H_fluctate_rate': '0.93',
#           'average_price': '737.3941',
#           'buy_price': '748',
#           'closing_price': '753',
#           'max_price': '757',
#           'min_price': '722',
#           'opening_price': '746',
#           'sell_price': '753',
#           'units_traded': '49800.68952767',
#           'volume_1day': '49800.68952767',
#           'volume_7day': '1658662.019945876963579857'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-4150',
#          '24H_fluctate_rate': '-5.66',
#          'average_price': '71293.0211',
#          'buy_price': '69100',
#          'closing_price': '69100',
#          'max_price': '74000',
#          'min_price': '68400',
#          'opening_price': '73250',
#          'sell_price': '69250',
#          'units_traded': '19729.55338594',
#          'volume_1day': '19729.55338594',
#          'volume_7day': '77826.33051199'},
#  'BTC': {'24H_fluctate': '-46000',
#          '24H_fluctate_rate': '-1.20',
#          'average_price': '3816202.4981',
#          'buy_price': '3780000',
#          'closing_price': '3779000',
#          'max_price': '3850000',
#          'min_price': '3757000',
#          'opening_price': '3825000',
#          'sell_price': '3781000',
#          'units_traded': '3486.99590732',
#          'volume_1day': '3486.99590732',
#          'volume_7day': '21558.95161339'},
#  'BTG': {'24H_fluctate': '320',
#          '24H_fluctate_rate': '3.11',
#          'average_price': '10468.9851',
#          'buy_price': '10520',
#          'closing_price': '10600',
#          'max_price': '10790',
#          'min_price': '10110',
#          'opening_price': '10280',
#          'sell_price': '10600',
#          'units_traded': '18876955.57519755',
#          'volume_1day': '18876955.57519755',
#          'volume_7day': '134429321.36306975'},
#  'BZNT': {'24H_fluctate': '-0.1',
#           '24H_fluctate_rate': '-0.37',
#           'average_price': '27.6026',
#           'buy_price': '26.9',
#           'closing_price': '26.9',
#           'max_price': '29.3',
#           'min_price': '26.6',
#           'opening_price': '27',
#           'sell_price': '27.1',
#           'units_traded': '11257655.42973499',
#           'volume_1day': '11257655.42973499',
#           'volume_7day': '75817567.985958839750308389'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.39',
#          'average_price': '25.8806',
#          'buy_price': '25.3',
#          'closing_price': '25.3',
#          'max_price': '26.7',
#          'min_price': '24.7',
#          'opening_price': '25.2',
#          'sell_price': '25.8',
#          'units_traded': '5536107.5961618',
#          'volume_1day': '5536107.5961618',
#          'volume_7day': '46119455.430549339087497181'},
#  'CTXC': {'24H_fluctate': '-2',
#           '24H_fluctate_rate': '-1.81',
#           'average_price': '109.3204',
#           'buy_price': '107',
#           'closing_price': '108',
#           'max_price': '113',
#           'min_price': '105',
#           'opening_price': '110',
#           'sell_price': '108',
#           'units_traded': '567577.34859439',
#           'volume_1day': '567577.34859439',
#           'volume_7day': '11571009.350517040273411807'},
#  'DASH': {'24H_fluctate': '-800',
#           '24H_fluctate_rate': '-1.08',
#           'average_price': '74349.6458',
#           'buy_price': '73000',
#           'closing_price': '73200',
#           'max_price': '76800',
#           'min_price': '72100',
#           'opening_price': '74000',
#           'sell_price': '73200',
#           'units_traded': '6168557.24686515',
#           'volume_1day': '6168557.24686515',
#           'volume_7day': '37319459.58063141'},
#  'ELF': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '1.81',
#          'average_price': '115.1572',
#          'buy_price': '111',
#          'closing_price': '112',
#          'max_price': '125',
#          'min_price': '108',
#          'opening_price': '110',
#          'sell_price': '112',
#          'units_traded': '3912008.46309922',
#          'volume_1day': '3912008.46309922',
#          'volume_7day': '16150817.977665019537578241'},
#  'ENJ': {'24H_fluctate': '0.7',
#          '24H_fluctate_rate': '2.22',
#          'average_price': '32.7154',
#          'buy_price': '32.3',
#          'closing_price': '32.2',
#          'max_price': '34.2',
#          'min_price': '31.4',
#          'opening_price': '31.5',
#          'sell_price': '33.6',
#          'units_traded': '681717.3198',
#          'volume_1day': '681717.3198',
#          'volume_7day': '10017816.050284802878061005'},
#  'EOS': {'24H_fluctate': '-94',
#          '24H_fluctate_rate': '-3.69',
#          'average_price': '2487.7761',
#          'buy_price': '2448',
#          'closing_price': '2447',
#          'max_price': '2559',
#          'min_price': '2404',
#          'opening_price': '2541',
#          'sell_price': '2450',
#          'units_traded': '1967083.03248497',
#          'volume_1day': '1967083.03248497',
#          'volume_7day': '9791870.50858918'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-157',
#          '24H_fluctate_rate': '-3.52',
#          'average_price': '4349.7764',
#          'buy_price': '4291',
#          'closing_price': '4298',
#          'max_price': '4474',
#          'min_price': '4219',
#          'opening_price': '4455',
#          'sell_price': '4299',
#          'units_traded': '54201.13121803',
#          'volume_1day': '54201.13121803',
#          'volume_7day': '305087.274713475489009608'},
#  'ETH': {'24H_fluctate': '-3900',
#          '24H_fluctate_rate': '-3.28',
#          'average_price': '116555.0741',
#          'buy_price': '114700',
#          'closing_price': '114800',
#          'max_price': '119800',
#          'min_price': '112800',
#          'opening_price': '118700',
#          'sell_price': '114900',
#          'units_traded': '95865.69733092',
#          'volume_1day': '95865.69733092',
#          'volume_7day': '430410.383449259606841027'},
#  'ETHOS': {'24H_fluctate': '12',
#            '24H_fluctate_rate': '7.69',
#            'average_price': '167.7036',
#            'buy_price': '167',
#            'closing_price': '168',
#            'max_price': '183',
#            'min_price': '146',
#            'opening_price': '156',
#            'sell_price': '169',
#            'units_traded': '5207885.58213667',
#            'volume_1day': '5207885.58213667',
#            'volume_7day': '28268412.62433831'},
#  'ETZ': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '4.03',
#          'average_price': '132.0227',
#          'buy_price': '127',
#          'closing_price': '129',
#          'max_price': '148',
#          'min_price': '121',
#          'opening_price': '124',
#          'sell_price': '129',
#          'units_traded': '12521890.76007147',
#          'volume_1day': '12521890.76007147',
#          'volume_7day': '26064257.487988197538683689'},
#  'GNT': {'24H_fluctate': '-3.4',
#          '24H_fluctate_rate': '-5.23',
#          'average_price': '63.7277',
#          'buy_price': '61.6',
#          'closing_price': '61.6',
#          'max_price': '66.5',
#          'min_price': '61.1',
#          'opening_price': '65',
#          'sell_price': '62',
#          'units_traded': '1445551.51753568',
#          'volume_1day': '1445551.51753568',
#          'volume_7day': '7597209.559218884663091948'},
#  'GTO': {'24H_fluctate': '-0.9',
#          '24H_fluctate_rate': '-3.26',
#          'average_price': '27.1622',
#          'buy_price': '26.7',
#          'closing_price': '26.7',
#          'max_price': '28.5',
#          'min_price': '26.1',
#          'opening_price': '27.6',
#          'sell_price': '27.2',
#          'units_traded': '3881440.59826108',
#          'volume_1day': '3881440.59826108',
#          'volume_7day': '55891018.68772461'},
#  'HC': {'24H_fluctate': '-42',
#         '24H_fluctate_rate': '-3.99',
#         'average_price': '1022.2792',
#         'buy_price': '1010',
#         'closing_price': '1010',
#         'max_price': '1070',
#         'min_price': '990',
#         'opening_price': '1052',
#         'sell_price': '1023',
#         'units_traded': '88396.72940448',
#         'volume_1day': '88396.72940448',
#         'volume_7day': '1049209.78124903'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '-6',
#          '24H_fluctate_rate': '-2.64',
#          'average_price': '225.1498',
#          'buy_price': '220',
#          'closing_price': '221',
#          'max_price': '245',
#          'min_price': '217',
#          'opening_price': '227',
#          'sell_price': '224',
#          'units_traded': '325126.13072162',
#          'volume_1day': '325126.13072162',
#          'volume_7day': '2528658.93172060774440284'},
#  'INS': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-1.39',
#          'average_price': '287.1945',
#          'buy_price': '279',
#          'closing_price': '283',
#          'max_price': '296',
#          'min_price': '273',
#          'opening_price': '287',
#          'sell_price': '283',
#          'units_traded': '408872.45257473',
#          'volume_1day': '408872.45257473',
#          'volume_7day': '2885914.7658766507'},
#  'IOST': {'24H_fluctate': '-0.46',
#           '24H_fluctate_rate': '-7.18',
#           'average_price': '6.096',
#           'buy_price': '5.85',
#           'closing_price': '5.94',
#           'max_price': '6.47',
#           'min_price': '5.77',
#           'opening_price': '6.4',
#           'sell_price': '5.94',
#           'units_traded': '27159892.18756515',
#           'volume_1day': '27159892.18756515',
#           'volume_7day': '145170389.818206974381241693'},
#  'ITC': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.70',
#          'average_price': '110.0981',
#          'buy_price': '108',
#          'closing_price': '108',
#          'max_price': '114',
#          'min_price': '105',
#          'opening_price': '111',
#          'sell_price': '112',
#          'units_traded': '299874.37011818',
#          'volume_1day': '299874.37011818',
#          'volume_7day': '2907563.728319016268785141'},
#  'KNC': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.51',
#          'average_price': '132.4768',
#          'buy_price': '129',
#          'closing_price': '130',
#          'max_price': '136',
#          'min_price': '129',
#          'opening_price': '132',
#          'sell_price': '130',
#          'units_traded': '667627.5628',
#          'volume_1day': '667627.5628',
#          'volume_7day': '4739370.036419997503071948'},
#  'LINK': {'24H_fluctate': '37',
#           '24H_fluctate_rate': '8.70',
#           'average_price': '450.2523',
#           'buy_price': '458',
#           'closing_price': '462',
#           'max_price': '499',
#           'min_price': '393',
#           'opening_price': '425',
#           'sell_price': '462',
#           'units_traded': '1875492.93048971',
#           'volume_1day': '1875492.93048971',
#           'volume_7day': '7643401.182461171388723166'},
#  'LOOM': {'24H_fluctate': '-4.6',
#           '24H_fluctate_rate': '-9.91',
#           'average_price': '43.849',
#           'buy_price': '42',
#           'closing_price': '41.8',
#           'max_price': '46.4',
#           'min_price': '41.8',
#           'opening_price': '46.4',
#           'sell_price': '42.8',
#           'units_traded': '1144238.64974518',
#           'volume_1day': '1144238.64974518',
#           'volume_7day': '5994786.062898338852353698'},
#  'LRC': {'24H_fluctate': '2.6',
#          '24H_fluctate_rate': '4.14',
#          'average_price': '65.6145',
#          'buy_price': '65.5',
#          'closing_price': '65.4',
#          'max_price': '71.9',
#          'min_price': '62.2',
#          'opening_price': '62.8',
#          'sell_price': '65.8',
#          'units_traded': '34282438.14862961',
#          'volume_1day': '34282438.14862961',
#          'volume_7day': '419894963.196744589561015935'},
#  'LTC': {'24H_fluctate': '-480',
#          '24H_fluctate_rate': '-1.39',
#          'average_price': '34104.628',
#          'buy_price': '33830',
#          'closing_price': '33870',
#          'max_price': '34870',
#          'min_price': '33500',
#          'opening_price': '34350',
#          'sell_price': '33870',
#          'units_traded': '6931.87357364',
#          'volume_1day': '6931.87357364',
#          'volume_7day': '65668.48094165'},
#  'MCO': {'24H_fluctate': '13',
#          '24H_fluctate_rate': '0.60',
#          'average_price': '2212.026',
#          'buy_price': '2152',
#          'closing_price': '2164',
#          'max_price': '2409',
#          'min_price': '2151',
#          'opening_price': '2151',
#          'sell_price': '2164',
#          'units_traded': '22806.82972646',
#          'volume_1day': '22806.82972646',
#          'volume_7day': '96262.8415715'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-2.4',
#           '24H_fluctate_rate': '-5.07',
#           'average_price': '46.737',
#           'buy_price': '44.8',
#           'closing_price': '44.9',
#           'max_price': '48.3',
#           'min_price': '44.8',
#           'opening_price': '47.3',
#           'sell_price': '44.9',
#           'units_traded': '9508346.2734628',
#           'volume_1day': '9508346.2734628',
#           'volume_7day': '49998041.974935036629269078'},
#  'MTL': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '1.20',
#          'average_price': '257.9444',
#          'buy_price': '252',
#          'closing_price': '251',
#          'max_price': '270',
#          'min_price': '244',
#          'opening_price': '248',
#          'sell_price': '259',
#          'units_traded': '319302.2317672',
#          'volume_1day': '319302.2317672',
#          'volume_7day': '5399739.13337233'},
#  'OCN': {'24H_fluctate': '-0.22',
#          '24H_fluctate_rate': '-8.52',
#          'average_price': '2.5408',
#          'buy_price': '2.36',
#          'closing_price': '2.36',
#          'max_price': '2.64',
#          'min_price': '2.3',
#          'opening_price': '2.58',
#          'sell_price': '2.37',
#          'units_traded': '29679170.80686245',
#          'volume_1day': '29679170.80686245',
#          'volume_7day': '211036451.144227052039125054'},
#  'OMG': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-0.24',
#          'average_price': '1221.0344',
#          'buy_price': '1206',
#          'closing_price': '1206',
#          'max_price': '1251',
#          'min_price': '1185',
#          'opening_price': '1209',
#          'sell_price': '1219',
#          'units_traded': '159189728.08120203',
#          'volume_1day': '159189728.08120203',
#          'volume_7day': '487146926.329385184328980677'},
#  'PAY': {'24H_fluctate': '13',
#          '24H_fluctate_rate': '4.77',
#          'average_price': '291.5545',
#          'buy_price': '285',
#          'closing_price': '285',
#          'max_price': '324',
#          'min_price': '268',
#          'opening_price': '272',
#          'sell_price': '287',
#          'units_traded': '6771342.65895319',
#          'volume_1day': '6771342.65895319',
#          'volume_7day': '117934247.241802434199370868'},
#  'PIVX': {'24H_fluctate': '-4',
#           '24H_fluctate_rate': '-0.54',
#           'average_price': '741.3554',
#           'buy_price': '731',
#           'closing_price': '732',
#           'max_price': '766',
#           'min_price': '708',
#           'opening_price': '736',
#           'sell_price': '739',
#           'units_traded': '106908.79862937',
#           'volume_1day': '106908.79862937',
#           'volume_7day': '2930188.07570418'},
#  'PLY': {'24H_fluctate': '-1.3',
#          '24H_fluctate_rate': '-4.40',
#          'average_price': '28.5788',
#          'buy_price': '28.1',
#          'closing_price': '28.2',
#          'max_price': '29.9',
#          'min_price': '27.2',
#          'opening_price': '29.5',
#          'sell_price': '28.2',
#          'units_traded': '4873563.23042712',
#          'volume_1day': '4873563.23042712',
#          'volume_7day': '32968651.316679626'},
#  'POLY': {'24H_fluctate': '-8',
#           '24H_fluctate_rate': '-6.83',
#           'average_price': '112.9065',
#           'buy_price': '109',
#           'closing_price': '109',
#           'max_price': '120',
#           'min_price': '108',
#           'opening_price': '117',
#           'sell_price': '111',
#           'units_traded': '1478243.55199261',
#           'volume_1day': '1478243.55199261',
#           'volume_7day': '6467444.436328878752046144'},
#  'POWR': {'24H_fluctate': '0.3',
#           '24H_fluctate_rate': '0.34',
#           'average_price': '89.1689',
#           'buy_price': '87.4',
#           'closing_price': '87.4',
#           'max_price': '92.9',
#           'min_price': '85.1',
#           'opening_price': '87.1',
#           'sell_price': '88.9',
#           'units_traded': '4219734.01915574',
#           'volume_1day': '4219734.01915574',
#           'volume_7day': '40192263.76598265'},
#  'PPT': {'24H_fluctate': '-41',
#          '24H_fluctate_rate': '-3.05',
#          'average_price': '1336.5833',
#          'buy_price': '1280',
#          'closing_price': '1300',
#          'max_price': '1416',
#          'min_price': '1300',
#          'opening_price': '1341',
#          'sell_price': '1299',
#          'units_traded': '23618.11162233',
#          'volume_1day': '23618.11162233',
#          'volume_7day': '505578.71531665'},
#  'PST': {'24H_fluctate': '-2.3',
#          '24H_fluctate_rate': '-2.35',
#          'average_price': '96.8316',
#          'buy_price': '95.2',
#          'closing_price': '95.2',
#          'max_price': '98.8',
#          'min_price': '93.6',
#          'opening_price': '97.5',
#          'sell_price': '97.5',
#          'units_traded': '623844.097',
#          'volume_1day': '623844.097',
#          'volume_7day': '9828442.098960081746785649'},
#  'QTUM': {'24H_fluctate': '-45',
#           '24H_fluctate_rate': '-2.18',
#           'average_price': '2039.7683',
#           'buy_price': '2015',
#           'closing_price': '2015',
#           'max_price': '2150',
#           'min_price': '1970',
#           'opening_price': '2060',
#           'sell_price': '2016',
#           'units_traded': '221352.99014032',
#           'volume_1day': '221352.99014032',
#           'volume_7day': '1097094.42202657'},
#  'RDN': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.44',
#          'average_price': '227.0578',
#          'buy_price': '223',
#          'closing_price': '223',
#          'max_price': '234',
#          'min_price': '219',
#          'opening_price': '224',
#          'sell_price': '226',
#          'units_traded': '499297.36494604',
#          'volume_1day': '499297.36494604',
#          'volume_7day': '8425789.254434199120712691'},
#  'REP': {'24H_fluctate': '490',
#          '24H_fluctate_rate': '3.95',
#          'average_price': '12829.9645',
#          'buy_price': '12890',
#          'closing_price': '12890',
#          'max_price': '13700',
#          'min_price': '12100',
#          'opening_price': '12400',
#          'sell_price': '12900',
#          'units_traded': '204732.22943043',
#          'volume_1day': '204732.22943043',
#          'volume_7day': '1296606.138744720025938939'},
#  'RNT': {'24H_fluctate': '1.3',
#          '24H_fluctate_rate': '1.88',
#          'average_price': '70.5889',
#          'buy_price': '70.3',
#          'closing_price': '70.3',
#          'max_price': '71.9',
#          'min_price': '69',
#          'opening_price': '69',
#          'sell_price': '71.2',
#          'units_traded': '3599156.45833465',
#          'volume_1day': '3599156.45833465',
#          'volume_7day': '63972844.945517874702176911'},
#  'ROM': {'24H_fluctate': '0.01',
#          '24H_fluctate_rate': '12.50',
#          'average_price': '0.0864',
#          'buy_price': '0.08',
#          'closing_price': '0.09',
#          'max_price': '0.09',
#          'min_price': '0.08',
#          'opening_price': '0.08',
#          'sell_price': '0.09',
#          'units_traded': '1084840504.39441111',
#          'volume_1day': '1084840504.39441111',
#          'volume_7day': '12200151567.347886666555555548'},
#  'SALT': {'24H_fluctate': '-6',
#           '24H_fluctate_rate': '-2.51',
#           'average_price': '235.1245',
#           'buy_price': '230',
#           'closing_price': '233',
#           'max_price': '243',
#           'min_price': '223',
#           'opening_price': '239',
#           'sell_price': '233',
#           'units_traded': '641788.44228501',
#           'volume_1day': '641788.44228501',
#           'volume_7day': '4918564.94939428'},
#  'SNT': {'24H_fluctate': '0.2',
#          '24H_fluctate_rate': '0.97',
#          'average_price': '20.9033',
#          'buy_price': '20.8',
#          'closing_price': '20.8',
#          'max_price': '21.5',
#          'min_price': '20.2',
#          'opening_price': '20.6',
#          'sell_price': '20.9',
#          'units_traded': '21116254.04874481',
#          'volume_1day': '21116254.04874481',
#          'volume_7day': '163298419.941210216947588824'},
#  'STEEM': {'24H_fluctate': '6',
#            '24H_fluctate_rate': '1.91',
#            'average_price': '323.7754',
#            'buy_price': '320',
#            'closing_price': '320',
#            'max_price': '338',
#            'min_price': '311',
#            'opening_price': '314',
#            'sell_price': '322',
#            'units_traded': '1240565.75070317',
#            'volume_1day': '1240565.75070317',
#            'volume_7day': '30614582.7349082'},
#  'STRAT': {'24H_fluctate': '1',
#            '24H_fluctate_rate': '0.10',
#            'average_price': '927.171',
#            'buy_price': '907',
#            'closing_price': '913',
#            'max_price': '970',
#            'min_price': '891',
#            'opening_price': '912',
#            'sell_price': '913',
#            'units_traded': '135289.39436414',
#            'volume_1day': '135289.39436414',
#            'volume_7day': '1678234.22022782'},
#  'THETA': {'24H_fluctate': '1.2',
#            '24H_fluctate_rate': '2.14',
#            'average_price': '57.4086',
#            'buy_price': '57.2',
#            'closing_price': '57.2',
#            'max_price': '61.1',
#            'min_price': '54.5',
#            'opening_price': '56',
#            'sell_price': '58',
#            'units_traded': '12010324.58527279',
#            'volume_1day': '12010324.58527279',
#            'volume_7day': '137535661.837002391595668157'},
#  'TMTG': {'24H_fluctate': '0.04',
#           '24H_fluctate_rate': '1.08',
#           'average_price': '3.7568',
#           'buy_price': '3.71',
#           'closing_price': '3.71',
#           'max_price': '3.97',
#           'min_price': '3.63',
#           'opening_price': '3.67',
#           'sell_price': '3.72',
#           'units_traded': '152918673.05136238',
#           'volume_1day': '152918673.05136238',
#           'volume_7day': '1804373590.720435371389347755'},
#  'TRUE': {'24H_fluctate': '-5',
#           '24H_fluctate_rate': '-2.09',
#           'average_price': '238.7647',
#           'buy_price': '233',
#           'closing_price': '234',
#           'max_price': '244',
#           'min_price': '234',
#           'opening_price': '239',
#           'sell_price': '238',
#           'units_traded': '167053.40406667',
#           'volume_1day': '167053.40406667',
#           'volume_7day': '7096196.774050689086769364'},
#  'TRX': {'24H_fluctate': '-0.9',
#          '24H_fluctate_rate': '-2.99',
#          'average_price': '29.9584',
#          'buy_price': '29.2',
#          'closing_price': '29.2',
#          'max_price': '31.4',
#          'min_price': '28.1',
#          'opening_price': '30.1',
#          'sell_price': '29.3',
#          'units_traded': '2166694868.60671953',
#          'volume_1day': '2166694868.60671953',
#          'volume_7day': '4584238773.22974418'},
#  'VET': {'24H_fluctate': '-0.02',
#          '24H_fluctate_rate': '-0.47',
#          'average_price': '4.277',
#          'buy_price': '4.18',
#          'closing_price': '4.18',
#          'max_price': '4.45',
#          'min_price': '4.16',
#          'opening_price': '4.2',
#          'sell_price': '4.24',
#          'units_traded': '75365946.49315646',
#          'volume_1day': '75365946.49315646',
#          'volume_7day': '1688237962.943777697215276127'},
#  'WAVES': {'24H_fluctate': '280',
#            '24H_fluctate_rate': '9.57',
#            'average_price': '3106.9825',
#            'buy_price': '3165',
#            'closing_price': '3204',
#            'max_price': '3316',
#            'min_price': '2850',
#            'opening_price': '2924',
#            'sell_price': '3222',
#            'units_traded': '435840.29879996',
#            'volume_1day': '435840.29879996',
#            'volume_7day': '3016925.46024767'},
#  'WAX': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '2.94',
#          'average_price': '35.3272',
#          'buy_price': '34.9',
#          'closing_price': '35',
#          'max_price': '37.2',
#          'min_price': '34',
#          'opening_price': '34',
#          'sell_price': '35',
#          'units_traded': '2342630.1805631',
#          'volume_1day': '2342630.1805631',
#          'volume_7day': '22693942.55804521'},
#  'WET': {'24H_fluctate': '-0.3',
#          '24H_fluctate_rate': '-2.63',
#          'average_price': '11.2161',
#          'buy_price': '11',
#          'closing_price': '11.1',
#          'max_price': '11.7',
#          'min_price': '10.7',
#          'opening_price': '11.4',
#          'sell_price': '11.1',
#          'units_traded': '34598335.34308471',
#          'volume_1day': '34598335.34308471',
#          'volume_7day': '133796363.831493997151592521'},
#  'WTC': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-0.36',
#          'average_price': '1095.2645',
#          'buy_price': '1068',
#          'closing_price': '1080',
#          'max_price': '1148',
#          'min_price': '1061',
#          'opening_price': '1084',
#          'sell_price': '1082',
#          'units_traded': '42879.93716633',
#          'volume_1day': '42879.93716633',
#          'volume_7day': '511033.366741901951337171'},
#  'XEM': {'24H_fluctate': '-2.8',
#          '24H_fluctate_rate': '-5.19',
#          'average_price': '52.4996',
#          'buy_price': '51',
#          'closing_price': '51.1',
#          'max_price': '56.2',
#          'min_price': '50',
#          'opening_price': '53.9',
#          'sell_price': '51.6',
#          'units_traded': '786691.47574511',
#          'volume_1day': '786691.47574511',
#          'volume_7day': '5719963.82840846'},
#  'XLM': {'24H_fluctate': '-7.3',
#          '24H_fluctate_rate': '-7.40',
#          'average_price': '95.291',
#          'buy_price': '91.2',
#          'closing_price': '91.3',
#          'max_price': '99.9',
#          'min_price': '90.4',
#          'opening_price': '98.6',
#          'sell_price': '91.4',
#          'units_traded': '16107735.01081825',
#          'volume_1day': '16107735.01081825',
#          'volume_7day': '81560304.16906526'},
#  'XMR': {'24H_fluctate': '-600',
#          '24H_fluctate_rate': '-1.24',
#          'average_price': '48451.8965',
#          'buy_price': '47250',
#          'closing_price': '47750',
#          'max_price': '49750',
#          'min_price': '47320',
#          'opening_price': '48350',
#          'sell_price': '47700',
#          'units_traded': '1935634.19790879',
#          'volume_1day': '1935634.19790879',
#          'volume_7day': '27806602.398298385269'},
#  'XRP': {'24H_fluctate': '-8',
#          '24H_fluctate_rate': '-2.44',
#          'average_price': '322.7844',
#          'buy_price': '319',
#          'closing_price': '319',
#          'max_price': '332',
#          'min_price': '313',
#          'opening_price': '327',
#          'sell_price': '320',
#          'units_traded': '48346529.70542834',
#          'volume_1day': '48346529.70542834',
#          'volume_7day': '202714739.02105978'},
#  'XVG': {'24H_fluctate': '-0.15',
#          '24H_fluctate_rate': '-2.25',
#          'average_price': '6.643',
#          'buy_price': '6.51',
#          'closing_price': '6.51',
#          'max_price': '6.8',
#          'min_price': '6.45',
#          'opening_price': '6.66',
#          'sell_price': '6.59',
#          'units_traded': '10635451.27683703',
#          'volume_1day': '10635451.27683703',
#          'volume_7day': '129737076.41739929'},
#  'ZEC': {'24H_fluctate': '-950',
#          '24H_fluctate_rate': '-1.75',
#          'average_price': '54400.3899',
#          'buy_price': '53200',
#          'closing_price': '53200',
#          'max_price': '56400',
#          'min_price': '52950',
#          'opening_price': '54150',
#          'sell_price': '53250',
#          'units_traded': '10265474.67365454',
#          'volume_1day': '10265474.67365454',
#          'volume_7day': '63080767.74969792'},
#  'ZIL': {'24H_fluctate': '-1.4',
#          '24H_fluctate_rate': '-5.98',
#          'average_price': '22.879',
#          'buy_price': '22',
#          'closing_price': '22',
#          'max_price': '24.1',
#          'min_price': '21.3',
#          'opening_price': '23.4',
#          'sell_price': '22.1',
#          'units_traded': '73453875.17328771',
#          'volume_1day': '73453875.17328771',
#          'volume_7day': '418106885.347598944347'},
#  'ZRX': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-0.71',
#          'average_price': '282.3533',
#          'buy_price': '278',
#          'closing_price': '277',
#          'max_price': '291',
#          'min_price': '276',
#          'opening_price': '279',
#          'sell_price': '279',
#          'units_traded': '251820.45944687',
#          'volume_1day': '251820.45944687',
#          'volume_7day': '5663615.411265400856955878'},
#  'date': '1548743400493'}

# %%
# 아래에 코드를 작성하세요.
for coin in
