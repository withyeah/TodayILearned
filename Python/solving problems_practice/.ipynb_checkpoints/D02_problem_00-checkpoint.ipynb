# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-55000',
#  '24H_fluctate_rate': '-1.43',
#  'average_price': '3802358.2393',
#  'buy_price': '3767000',
#  'closing_price': '3772000',
#  'date': '1548758475817',
#  'max_price': '3848000',
#  'min_price': '3736000',
#  'opening_price': '3827000',
#  'sell_price': '3772000',
#  'units_traded': '3540.98284879',
#  'volume_1day': '3540.98284879',
#  'volume_7day': '21583.36021759'}

# %%
# 아래에 코드를 작성하세요.
price = int(btc['max_price'])-int(btc['min_price'])+int(btc['opening_price'])
print('상승장' if price > int(btc['max_price']) else '하락장')
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-1.9',
#          '24H_fluctate_rate': '-2.63',
#          'average_price': '69.9367',
#          'buy_price': '70',
#          'closing_price': '70.2',
#          'max_price': '74.5',
#          'min_price': '66',
#          'opening_price': '72.1',
#          'sell_price': '70.1',
#          'units_traded': '488996.29910345',
#          'volume_1day': '488996.29910345',
#          'volume_7day': '5765338.757903682861539247'},
#  'ADA': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-2.34',
#          'average_price': '41.9627',
#          'buy_price': '41.5',
#          'closing_price': '41.6',
#          'max_price': '43.3',
#          'min_price': '40.7',
#          'opening_price': '42.6',
#          'sell_price': '41.6',
#          'units_traded': '7788719.13132749',
#          'volume_1day': '7788719.13132749',
#          'volume_7day': '51132047.00779196'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-2',
# ...

# %%
# 아래에 코드를 작성하세요.
for key in currency.keys():
    coin = key
    if type(currency[key]) == dict:
        price = float(currency[key]['max_price'])-float(currency[key]['min_price'])+float(currency[key]['opening_price'])
        print(f'{coin} 상승장' if price > float(btc['max_price']) else f'{coin} 하락장')
# Out:
# BTC 상승장
# ETH 하락장
# DASH 하락장
# LTC 하락장
# ETC 하락장
# XRP 하락장
# BCH 하락장
# XMR 하락장
# ZEC 하락장
# QTUM 하락장
# BTG 하락장
# EOS 하락장
# ICX 하락장
# VET 하락장
# TRX 하락장
# ELF 하락장
# MITH 하락장
# MCO 하락장
# OMG 하락장
# KNC 하락장
# GNT 하락장
# ZIL 하락장
# ETHOS 하락장
# PAY 하락장
# WAX 하락장
# POWR 하락장
# LRC 하락장
# GTO 하락장
# STEEM 하락장
# STRAT 하락장
# ZRX 하락장
# REP 하락장
# AE 하락장
# XEM 하락장
# SNT 하락장
# ADA 하락장
# PPT 하락장
# CTXC 하락장
# CMT 하락장
# THETA 하락장
# WTC 하락장
# ITC 하락장
# TRUE 하락장
# ABT 하락장
# RNT 하락장
# PLY 하락장
# WAVES 하락장
# LINK 하락장
# ENJ 하락장
# PST 하락장
# SALT 하락장
# RDN 하락장
# LOOM 하락장
# BHPC 하락장
# PIVX 하락장
# INS 하락장
# BCD 하락장
# BZNT 하락장
# XLM 하락장
# OCN 하락장
# BSV 하락장
# TMTG 하락장
# BAT 하락장
# WET 하락장
# XVG 하락장
# IOST 하락장
# POLY 하락장
# HC 하락장
# ROM 하락장
# AMO 하락장
# ETZ 하락장
# ARN 하락장
# APIS 하락장
# MTL 하락장
